# %% [markdown]
# # NHK Easy Hard Classifier Pipeline

# %%
# 1. Load the data
from data.loader import load_NHK_dataset
X, y = load_NHK_dataset()

# %%
# 2. Transform the dataset
from preprocessing.transformer import transform_dataset
X, y = transform_dataset(X, y)

# %%
# 3. Build the model
from training.model import RNN
rnn = RNN()

# %%
# 4. Train the model
from training.train import train
losses = train(rnn, X, y)
# Out:
# Current model has highest training accuracy of 83.5
# 1000 epochs	0.4503089070171118 loss	83.5% train acc
# 2000 epochs	0.4620798235461116 loss	82.19999999999999% train acc
# Current model has highest training accuracy of 84.1
# 3000 epochs	0.4304633443728089 loss	84.1% train acc
# Current model has highest training accuracy of 84.7
# 4000 epochs	0.41932153180707243 loss	84.7% train acc
# Current model has highest training accuracy of 84.6
# 5000 epochs	0.42171841389779 loss	84.6% train acc
# Current model has highest training accuracy of 85.9
# 6000 epochs	0.37242116752034055 loss	85.9% train acc
# 7000 epochs	0.4288206896544434 loss	83.3% train acc
# Current model has highest training accuracy of 86.4
# 8000 epochs	0.376501500868937 loss	86.4% train acc
# 9000 epochs	0.37778800767241044 loss	85.6% train acc
# 10000 epochs	0.3804472130537033 loss	84.2% train acc
# 11000 epochs	0.36853919782931915 loss	85.5% train acc
# 12000 epochs	0.3726233992336784 loss	85.0% train acc
# 13000 epochs	0.3764222118244506 loss	85.2% train acc
# 14000 epochs	0.363188517391216 loss	85.0% train acc
# 15000 epochs	nan loss	61.6% train acc
# 16000 epochs	nan loss	16.1% train acc
# 17000 epochs	nan loss	15.5% train acc
# 18000 epochs	nan loss	15.6% train acc
# 19000 epochs	nan loss	15.9% train acc
# 20000 epochs	nan loss	15.2% train acc
# 21000 epochs	nan loss	17.0% train acc
# 22000 epochs	nan loss	15.5% train acc
# 23000 epochs	nan loss	14.299999999999999% train acc
# 24000 epochs	nan loss	17.0% train acc
# 25000 epochs	nan loss	14.2% train acc
# 26000 epochs	nan loss	13.700000000000001% train acc
# 27000 epochs	nan loss	15.6% train acc
# 28000 epochs	nan loss	14.899999999999999% train acc
# 29000 epochs	nan loss	14.899999999999999% train acc
# 30000 epochs	nan loss	13.8% train acc
# 31000 epochs	nan loss	13.5% train acc
# 32000 epochs	nan loss	15.299999999999999% train acc
# 33000 epochs	nan loss	14.099999999999998% train acc
# 34000 epochs	nan loss	16.3% train acc
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-7868acdf9696> in <module>
#       1 # 4. Train the model
#       2 from training.train import train
# ----> 3 losses = train(rnn, X, y)
#
# ~/dev/code/projects/language-study-aid/languages/japanese/models/training/train.py in train(model, X, y)
#      70             class_tensor = mini_batch_y[idx]
#      71             # pass the class and sentence into the train function
# ---> 72             output, loss = step(model, article_tensor, class_tensor)
#      73             # accummulate the loss
#      74             current_loss += loss
#
# ~/dev/code/projects/language-study-aid/languages/japanese/models/training/train.py in step(model, input_tensor, class_tensor)
#      23
#      24     loss = model.criterion(output, class_tensor)
# ---> 25     loss.backward()
#      26
#      27     # Add parameters' gradients to their values, multiplied by learning rate
#
# /usr/local/lib/python3.7/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     100                 products. Defaults to ``False``.
#     101         """
# --> 102         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     103
#     104     def register_hook(self, hook):
#
# /usr/local/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      88     Variable._execution_engine.run_backward(
#      89         tensors, grad_tensors, retain_graph, create_graph,
# ---> 90         allow_unreachable=True)  # allow_unreachable flag
#      91
#      92
#
# KeyboardInterrupt:

# %%
# 5. Report the losses
# %matplotlib inline

from training.analysis import *

loss = load_statistic("losses")
acc = load_statistic("train_acc")

report_loss(loss)
report_accuracy(acc)
